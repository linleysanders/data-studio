# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %matplotlib inline

# %%
df = pd.read_csv("State_Averages.csv")
df.head()
# Out:
#   State or Nation  Cycle 1 Total Number of Health Deficiencies  \
# 0          NATION                                          NaN
# 1              AK                                          NaN
# 2              AL                                          NaN
# 3              AR                                          NaN
# 4              AZ                                          NaN
#
#    Cycle 1 Total Number of Fire Safety Deficiencies  \
# 0                                               3.0
# 1                                               3.8
# 2                                               3.3
# 3                                               0.8
# 4                                               2.8
#
#    Cycle 2 Total Number of Health Deficiencies  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Cycle 2 Total Number of Fire Safety Deficiencies  \
# 0                                               3.0
# 1                                               4.9
# 2                                               3.1
# 3                                               0.6
# 4                                               2.6
#
#    Cycle 3 Total Number of Health Deficiencies  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Cycle 3 Total Number of Fire Safety Deficiencies  \
# 0                                               3.0
# 1                                               3.3
# 2                                               3.7
# 3                                               0.7
# 4                                               3.5
#
#    Previous Survey Number of Health Deficiencies  \
# 0                                            5.8
# 1                                            9.6
# 2                                            4.1
# 3                                            4.5
# 4                                            3.6
#
#    Average Number of Residents Per Day  \
# 0                                 86.4
# 1                                 35.7
# 2                                 99.6
# 3                                 79.4
# 4                                 79.0
#
#    Reported Nurse Aide Staffing Hours per Resident per Day       ...        \
# 0                                               2.32             ...
# 1                                               4.27             ...
# 2                                               2.52             ...
# 3                                               2.70             ...
# 4                                               2.38             ...
#
#    Percentage of short stay residents who were assessed and appropriately given the seasonal influenza vaccine  \
# 0                                         81.478004%
# 1                                         85.833141%
# 2                                         81.662465%
# 3                                         81.700609%
# 4                                         88.790855%
#
#    Percentage of short stay residents assessed and appropriately given the pneumococcal vaccine  \
# 0                                         83.291367%
# 1                                         82.246366%
# 2                                         83.702514%
# 3                                         82.614705%
# 4                                          92.26058%
#
#    Percentage of short stay residents who newly received an antipsychotic medication  \
# 0                                          1.977782%
# 1                                          1.950982%
# 2                                          2.259746%
# 3                                          2.157267%
# 4                                          1.300158%
#
#    Percentage of long stay residents whose ability to move independently worsened  \
# 0                                          18.25062%
# 1                                         21.486559%
# 2                                         15.322916%
# 3                                         16.108273%
# 4                                         19.777646%
#
#    Percentage of long stay residents who received an antianxiety or hypnotic medication  \
# 0                                         22.446278%
# 1                                         17.845459%
# 2                                         28.648515%
# 3                                         25.886907%
# 4                                         21.391274%
#
#    Percentage of short stay residents who made improvements in function  \
# 0                                         67.793374%
# 1                                          70.68435%
# 2                                         62.019543%
# 3                                         69.649043%
# 4                                         65.106865%
#
#    Percentage of short stay residents who were rehospitalized after a nursing home admission  \
# 0                                         21.100346%
# 1                                         12.200076%
# 2                                         21.743648%
# 3                                         24.869366%
# 4                                         21.481093%
#
#   Percentage of short stay residents who had an outpatient emergency department visit  \
# 0                                         11.859575%
# 1                                          8.222515%
# 2                                         10.583969%
# 3                                         15.939919%
# 4                                         11.788992%
#
#   Percentage of short stay residents who were successfully discharged to the community  \
# 0                                         57.029904%
# 1                                         68.127998%
# 2                                         58.989532%
# 3                                         52.397543%
# 4                                         62.972374%
#
#   Processing Date
# 0      06/01/2018
# 1      06/01/2018
# 2      06/01/2018
# 3      06/01/2018
# 4      06/01/2018
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Percentage of long-stay residents who have symptoms of depression
# This shows you the percentage of patients with signs of depression. Depression is a medical problem of the brain that can affect how you think, feel, and behave.
# Lower percentages are better.

# %%
depression = df[['State or Nation', 'Average Number of Residents Per Day', 'Percent of Long Stay Residents Who Have Depressive Symptoms']]
depression.sort_values(by='Percent of Long Stay Residents Who Have Depressive Symptoms', ascending=False).head(10)
# Out:
#    State or Nation  Average Number of Residents Per Day  \
# 50              WA                                 75.3
# 23              ME                                 59.8
# 49              VT                                 69.3
# 17              IN                                 70.8
# 47              UT                                 54.4
# 36              NY                                168.3
# 1               AK                                 35.7
# 18              KS                                 52.1
# 30              ND                                 69.4
# 11              GA                                 92.6
#
#    Percent of Long Stay Residents Who Have Depressive Symptoms
# 50                                          9.974658%
# 23                                          8.482571%
# 49                                          8.365873%
# 17                                          7.797748%
# 47                                          7.369904%
# 36                                          6.886257%
# 1                                           6.578682%
# 18                                          5.970667%
# 30                                          5.172228%
# 11                                             5.152%

# %%
#Major Depressive Episode in the Past Year Among Adults
national_avg = pd.read_csv("Average_Depression_States.csv")
national_avg.head()
# Out:
#   State Code State_Region Nation_State Small Area Estimate 95% CI (Lower)  \
# 0         AL      Alabama      Alabama               6.82%          5.87%
# 1         AK       Alaska       Alaska               6.93%          6.02%
# 2         AZ      Arizona      Arizona               6.43%          5.51%
# 3         AR     Arkansas     Arkansas               7.98%          6.94%
# 4         CA   California   California               6.10%          5.61%
#
#   95% CI (Upper)  Type
# 0          7.92%     3
# 1          7.97%     3
# 2          7.48%     3
# 3          9.17%     3
# 4          6.62%     3

# %%
df_compare = national_avg.merge(depression, left_on='State Code', right_on='State or Nation')
df_compare.head()
# Out:
#   State Code State_Region Nation_State Small Area Estimate 95% CI (Lower)  \
# 0         AL      Alabama      Alabama               6.82%          5.87%
# 1         AK       Alaska       Alaska               6.93%          6.02%
# 2         AZ      Arizona      Arizona               6.43%          5.51%
# 3         AR     Arkansas     Arkansas               7.98%          6.94%
# 4         CA   California   California               6.10%          5.61%
#
#   95% CI (Upper)  Type State or Nation  Average Number of Residents Per Day  \
# 0          7.92%     3              AL                                 99.6
# 1          7.97%     3              AK                                 35.7
# 2          7.48%     3              AZ                                 79.0
# 3          9.17%     3              AR                                 79.4
# 4          6.62%     3              CA                                 86.6
#
#   Percent of Long Stay Residents Who Have Depressive Symptoms
# 0                                          1.143164%
# 1                                          6.578682%
# 2                                          2.392781%
# 3                                          1.936882%
# 4                                          0.743524%

# %%
df_compare = df_compare.drop('Type', axis=1)
df_compare.head()
# Out:
#   State Code State_Region Nation_State Small Area Estimate 95% CI (Lower)  \
# 0         AL      Alabama      Alabama               6.82%          5.87%
# 1         AK       Alaska       Alaska               6.93%          6.02%
# 2         AZ      Arizona      Arizona               6.43%          5.51%
# 3         AR     Arkansas     Arkansas               7.98%          6.94%
# 4         CA   California   California               6.10%          5.61%
#
#   95% CI (Upper) State or Nation  Average Number of Residents Per Day  \
# 0          7.92%              AL                                 99.6
# 1          7.97%              AK                                 35.7
# 2          7.48%              AZ                                 79.0
# 3          9.17%              AR                                 79.4
# 4          6.62%              CA                                 86.6
#
#   Percent of Long Stay Residents Who Have Depressive Symptoms
# 0                                          1.143164%
# 1                                          6.578682%
# 2                                          2.392781%
# 3                                          1.936882%
# 4                                          0.743524%

# %%
df_compare.rename(columns={'State_Region': 'State'}, inplace=True)
df_compare.rename(columns={'Small Area Estimate': 'State Depression Average'}, inplace=True)
df_compare.rename(columns={'Average Number of Residents Per Day': 'Avg Number Daily Residents'}, inplace=True)
df_compare.rename(columns={'State Depression Average': 'State_Depression_Average'}, inplace=True)
df_compare.rename(columns={'Percent of Long Stay Residents Who Have Depressive Symptoms': 'Elderly_Depression'}, inplace=True)

# %%
df_compare = df_compare.drop("State or Nation", axis=1)
df_compare = df_compare.drop("Nation_State", axis=1)
df_compare = df_compare.drop("95% CI (Lower)", axis=1)
df_compare = df_compare.drop("95% CI (Upper)", axis=1)

# %%
df_compare.sort_values(by='Elderly_Depression', ascending=False)
# Out:
#    State Code                 State State_Depression_Average  \
# 44         WA            Washington                    7.82%
# 18         ME                 Maine                    7.45%
# 42         VT               Vermont                    7.99%
# 14         IN               Indiana                    7.59%
# 41         UT                  Utah                    7.53%
# 31         NY              New York                    6.53%
# 1          AK                Alaska                    6.93%
# 16         KS                Kansas                    7.25%
# 33         ND          North Dakota                    6.50%
# 10         GA               Georgia                    6.51%
# 46         WI             Wisconsin                    6.66%
# 35         OK              Oklahoma                    7.04%
# 15         IA                  Iowa                    6.72%
# 26         NE              Nebraska                    7.00%
# 30         NM            New Mexico                    6.75%
# 12         ID                 Idaho                    7.40%
# 45         WV         West Virginia                    8.31%
# 23         MN               Montana                    7.26%
# 22         MN             Minnesota                    7.28%
# 47         WY               Wyoming                    7.53%
# 5          CO              Colorado                    7.50%
# 40         TX                 Texas                    5.53%
# 28         NH         New Hampshire                    8.59%
# 19         MD              Maryland                    6.42%
# 37         RI          Rhode Island                    7.14%
# 25         MO              Missouri                    6.97%
# 36         OR                Oregon                    7.95%
# 21         MI              Michigan                    6.60%
# 43         VA              Virginia                    7.77%
# 11         HI                Hawaii                    5.36%
# 2          AZ               Arizona                    6.43%
# 27         NV                Nevada                    7.14%
# 32         NC        North Carolina                    7.20%
# 20         MA         Massachusetts                    7.49%
# 7          DE              Delaware                    6.62%
# 39         TN             Tennessee                    7.06%
# 13         IL              Illinois                    5.84%
# 34         OH                  Ohio                    7.54%
# 3          AR              Arkansas                    7.98%
# 29         NJ            New Jersey                    6.49%
# 6          CT           Connecticut                    6.64%
# 17         LA             Louisiana                    6.52%
# 24         MS           Mississippi                    6.06%
# 38         SC        South Carolina                    6.53%
# 0          AL               Alabama                    6.82%
# 9          FL               Florida                    5.98%
# 4          CA            California                    6.10%
# 8          DC  District of Columbia                    7.14%
#
#     Avg Number Daily Residents Elderly_Depression
# 44                        75.3          9.974658%
# 18                        59.8          8.482571%
# 42                        69.3          8.365873%
# 14                        70.8          7.797748%
# 41                        54.4          7.369904%
# 31                       168.3          6.886257%
# 1                         35.7          6.578682%
# 16                        52.1          5.970667%
# 33                        69.4          5.172228%
# 10                        92.6             5.152%
# 46                        64.5          4.949912%
# 35                        61.3          4.876544%
# 15                        54.1          4.796637%
# 26                        52.6          4.752031%
# 30                        78.7           4.72614%
# 12                        50.8          4.708949%
# 45                        77.0          4.347196%
# 23                        65.9          4.231493%
# 22                        65.9          4.231493%
# 47                        62.0           4.05991%
# 5                         73.9          3.675596%
# 40                        78.5          3.646198%
# 28                        87.7          3.601019%
# 19                       108.6          3.559829%
# 37                        95.7           3.31988%
# 25                        73.2          3.287699%
# 36                        54.2          3.015568%
# 21                        87.4          2.695002%
# 43                        97.9          2.691173%
# 11                        86.2          2.609457%
# 2                         79.0          2.392781%
# 27                        94.7          2.305042%
# 32                        85.2          2.267479%
# 20                        97.0          2.170979%
# 7                         92.3          2.115345%
# 39                        87.1           2.01822%
# 13                        91.5         18.786234%
# 34                        76.9         12.788614%
# 3                         79.4          1.936882%
# 29                       120.6          1.724259%
# 6                        102.6          1.590505%
# 17                        94.2          1.314159%
# 24                        78.2           1.31361%
# 38                        91.8          1.302292%
# 0                         99.6          1.143164%
# 9                        107.2          1.078708%
# 4                         86.6          0.743524%
# 8                        132.0          0.734532%

# %%
elders = df_compare.sort_values(by='Elderly_Depression', ascending=False)
elders = elders[['State', 'State_Depression_Average', 'Elderly_Depression']]
elders.head()
# Out:
#          State State_Depression_Average Elderly_Depression
# 44  Washington                    7.82%          9.974658%
# 18       Maine                    7.45%          8.482571%
# 42     Vermont                    7.99%          8.365873%
# 14     Indiana                    7.59%          7.797748%
# 41        Utah                    7.53%          7.369904%

# %% [markdown]
# ## Write a function to compare ` State_Depression_Average` to `Elderly Depression`

# %%
elders.State_Depression_Average = elders.State_Depression_Average.str.strip("%""")
elders.Elderly_Depression = elders.Elderly_Depression.str.strip("%""")

# %%
elders.State_Depression_Average = elders.State_Depression_Average.astype(float)
elders.Elderly_Depression = elders.Elderly_Depression.astype(float)

# %%
#avg_list = list(elders['State_Depression_Average'])
#avg_list

# %%
elder_list = list(elders['Elderly_Depression'])
elder_list
# Out:
# [9.974658,
#  8.482571,
#  8.365873,
#  7.797748,
#  7.369904,
#  6.886257,
#  6.578682,
#  5.970667,
#  5.172228,
#  5.152,
#  4.949912,
#  4.876544,
#  4.796637,
#  4.752031,
#  4.72614,
#  4.708949,
#  4.347196,
#  4.231493,
#  4.231493,
#  4.05991,
#  3.675596,
#  3.646198,
#  3.601019,
#  3.559829,
#  3.31988,
#  3.287699,
#  3.015568,
#  2.695002,
#  2.691173,
#  2.609457,
#  2.392781,
#  2.305042,
#  2.267479,
#  2.170979,
#  2.115345,
#  2.01822,
#  18.786234,
#  12.788614,
#  1.936882,
#  1.724259,
#  1.590505,
#  1.314159,
#  1.31361,
#  1.302292,
#  1.143164,
#  1.078708,
#  0.743524,
#  0.734532]

# %% [markdown]
# # Function to Determine Where the Medicaid Depression Exceeds State Average

# %%
def depression_compare(row):
    
        if row['Elderly_Depression'] > row['State_Depression_Average']:
            return "Exceeds Average"
        
elders['Spike'] = elders.apply(depression_compare, axis=1)

# %%
spike = elders.sort_values(by='Spike').head(7)
spike['Difference'] = 1 - spike['State_Depression_Average']/spike['Elderly_Depression']
spike
# Out:
#          State  State_Depression_Average  Elderly_Depression            Spike  \
# 44  Washington                      7.82            9.974658  Exceeds Average
# 18       Maine                      7.45            8.482571  Exceeds Average
# 42     Vermont                      7.99            8.365873  Exceeds Average
# 14     Indiana                      7.59            7.797748  Exceeds Average
# 31    New York                      6.53            6.886257  Exceeds Average
# 13    Illinois                      5.84           18.786234  Exceeds Average
# 34        Ohio                      7.54           12.788614  Exceeds Average
#
#     Difference
# 44    0.216013
# 18    0.121729
# 42    0.044929
# 14    0.026642
# 31    0.051734
# 13    0.689134
# 34    0.410413

# %%
difference = spike.sort_values(by='Difference', ascending=False)
difference
# Out:
#          State  State_Depression_Average  Elderly_Depression            Spike  \
# 13    Illinois                      5.84           18.786234  Exceeds Average
# 34        Ohio                      7.54           12.788614  Exceeds Average
# 44  Washington                      7.82            9.974658  Exceeds Average
# 18       Maine                      7.45            8.482571  Exceeds Average
# 31    New York                      6.53            6.886257  Exceeds Average
# 42     Vermont                      7.99            8.365873  Exceeds Average
# 14     Indiana                      7.59            7.797748  Exceeds Average
#
#     Difference
# 13    0.689134
# 34    0.410413
# 44    0.216013
# 18    0.121729
# 31    0.051734
# 42    0.044929
# 14    0.026642

# %%
spike
# Out:
#          State  State_Depression_Average  Elderly_Depression            Spike  \
# 44  Washington                      7.82            9.974658  Exceeds Average
# 18       Maine                      7.45            8.482571  Exceeds Average
# 42     Vermont                      7.99            8.365873  Exceeds Average
# 14     Indiana                      7.59            7.797748  Exceeds Average
# 31    New York                      6.53            6.886257  Exceeds Average
# 13    Illinois                      5.84           18.786234  Exceeds Average
# 34        Ohio                      7.54           12.788614  Exceeds Average
#
#     Difference
# 44    0.216013
# 18    0.121729
# 42    0.044929
# 14    0.026642
# 31    0.051734
# 13    0.689134
# 34    0.410413

# %%
bar_colors = ['#CE4E44', '#696969'] 

ax = difference.sort_values(by='Elderly_Depression', ascending=False).plot(kind='bar', x='State', y=['Elderly_Depression', 'State_Depression_Average'], rot= 0, color=bar_colors)

ax.set_title("Where America's Elderly Report Higher Rates of Depression", pad=30, fontsize=20)
ax.title.set_fontname('Lao Sangam MN')

ax.set_xlabel("Percentage of Elderly With Depressive Symptoms")
ax.set_ylabel("State Average for Depressive Episodes")

ax.set_ylim((0, 20))

plt.gcf().text(0.5, .93, "States where the elderly in Medicaid nursing homes are more likely to be depressed than the average adult.", ha='center', fontsize=10)
    
ax.text(-.1, 19, "68% more likely")
ax.text(.4, 14, "41% more likely")
ax.text(1.2, 11, "21% more likely")
ax.text(2.7, 9, "12% more likely")
#ax.text(4, 8.8, "4% more likely")
#ax.text(5, 8.5, "2% more likely")
#ax.text(6, 8.0, "5% more likely")

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['right'].set_visible(False)

plt.rcParams.update({  

  'patch.linewidth': 0.2,
  'patch.facecolor': '#348ABD',
  'patch.edgecolor': '#EEEEEE',
  'patch.antialiased': True,
  'font.size': 9.0,
  'axes.edgecolor': 'black',
  'axes.grid': False,
  'axes.linewidth': 1.5,
  'axes.labelsize': 'large',
  'axes.labelcolor': 'black',

})

# %%
bar_colors = ['#696969', '#CE4E44'] 

ax = difference.sort_values(by='Elderly_Depression', ascending=True).plot(kind='barh', x='State', y=['State_Depression_Average', 'Elderly_Depression'], figsize=(10, 5), color=bar_colors)

ax.set_title("Where America's Elderly Report Higher Rates of Depression", pad=30, fontsize=20)
ax.title.set_fontname('Lao Sangam MN')

ax.set_xlabel("Percentage of Elderly With Depressive Symptoms")
ax.set_ylabel("State Average for Depressive Episodes")
ax.set_xlim((0, 20))

plt.gcf().text(0.5, .93, "States where the elderly in Medicaid nursing homes are more likely to be depressed than the average adult.", ha='center', fontsize=10)
    
#ax.text(-.1, 19, "68% more likely")
#ax.text(.4, 14, "41% more likely")
#ax.text(1.2, 11, "21% more likely")
#ax.text(2.7, 9, "12% more likely")
#ax.text(4, 8.8, "4% more likely")
#ax.text(5, 8.5, "2% more likely")
#ax.text(6, 8.0, "5% more likely")

ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)
ax.spines['right'].set_visible(False)

plt.rcParams.update({  

  'patch.linewidth': 0.2,
  'patch.facecolor': '#348ABD',
  'patch.edgecolor': '#EEEEEE',
  'patch.antialiased': True,
  'font.size': 9.0,
  'axes.edgecolor': 'black',
  'axes.grid': False,
  'axes.linewidth': 1.5,
  'axes.labelsize': 'large',
  'axes.labelcolor': 'black',

})

# %%
#Dig into Illinois, Ohio, Washington, Maine
top_states = df.loc[df['State or Nation'].isin(['IL','ME', "OH", "WA"])]
top_states[['State or Nation', 'Average Number of Residents Per Day', 'Percentage of long stay residents who received an antianxiety or hypnotic medication', 'Number of Fines', 'Fine Amount in Dollars']]
# Out:
#    State or Nation  Average Number of Residents Per Day  \
# 16              IL                                 91.5
# 23              ME                                 59.8
# 37              OH                                 76.9
# 50              WA                                 75.3
#
#    Percentage of long stay residents who received an antianxiety or hypnotic medication  \
# 16                                         21.510821%
# 23                                          18.66007%
# 37                                         24.014571%
# 50                                         15.317052%
#
#     Number of Fines  Fine Amount in Dollars
# 16              0.3                  6106.0
# 23              0.1                  1174.0
# 37              0.4                  7630.0
# 50              1.5                 41639.0

# %% [markdown]
# ## I think I'm going to need to sort through and count the deficiencies // There are 344,584 of them!

# %%
import glob

# %%
filenames = glob.glob("Deficiencies/*.csv")
filenames
# Out:
# ['Deficiencies/Deficiencies Cycle 1.csv',
#  'Deficiencies/Deficiencies Cycle 2.csv',
#  'Deficiencies/Deficiencies Cycle 3.csv']

# %%
dataframes = []

for filename in filenames:
    df = pd.read_csv(filename)
    df['filename'] = filename
    dataframes.append(df)

everything = pd.concat(dataframes, ignore_index=True)
everything.shape
# Out:
# (344584, 15)

# %%
everything
# Out:
#        Federal Provider Number  \
# 0                       676395
# 1                       676413
# 2                       676406
# 3                       676389
# 4                       676416
# 5                       676383
# 6                       676406
# 7                       676388
# 8                       676383
# 9                       676391
# 10                      676416
# 11                      676383
# 12                      676417
# 13                      676413
# 14                      676389
# 15                      676416
# 16                      676391
# 17                      676423
# 18                      676395
# 19                      676386
# 20                      676416
# 21                      676397
# 22                      676428
# 23                      676383
# 24                      676409
# 25                      676403
# 26                      676389
# 27                      676383
# 28                      676402
# 29                      676391
# ...                        ...
# 344554                  676355
# 344555                  676355
# 344556                  676355
# 344557                  676355
# 344558                  676355
# 344559                  676355
# 344560                  676355
# 344561                  676355
# 344562                  676355
# 344563                  676355
# 344564                  676355
# 344565                  676360
# 344566                  676360
# 344567                  676360
# 344568                  676360
# 344569                  676360
# 344570                  676360
# 344571                  676360
# 344572                  676360
# 344573                  676360
# 344574                  676360
# 344575                  676370
# 344576                  676370
# 344577                  676370
# 344578                  676370
# 344579                  676379
# 344580                  676379
# 344581                  676379
# 344582                  676379
# 344583                  676379
#
#                                             Provider Name Survey Date  \
# 0                          THE HEALTHCARE RESORT OF PLANO  06/07/2017
# 1       LEGEND OAKS HEALTHCARE AND REHABILITATION GARLAND  03/29/2018
# 2                          TRUCARE LIVING CENTERS - SELMA  08/10/2017
# 3                MATADOR HEALTH AND REHABILITATION CENTER  08/17/2017
# 4                              BRIGHTPOINTE AT LYTLE LAKE  05/26/2017
# 5                                      INSPIRE NEW BOSTON  05/05/2017
# 6                          TRUCARE LIVING CENTERS - SELMA  08/10/2017
# 7                               THE PAVILION AT CREEKWOOD  07/13/2017
# 8                                      INSPIRE NEW BOSTON  05/05/2017
# 9                                        WINDSOR CALALLEN  02/02/2018
# 10                             BRIGHTPOINTE AT LYTLE LAKE  05/26/2017
# 11                                     INSPIRE NEW BOSTON  05/05/2017
# 12                           STERLING OAKS REHABILITATION  06/22/2017
# 13      LEGEND OAKS HEALTHCARE AND REHABILITATION GARLAND  03/29/2018
# 14               MATADOR HEALTH AND REHABILITATION CENTER  08/17/2017
# 15                             BRIGHTPOINTE AT LYTLE LAKE  05/26/2017
# 16                                       WINDSOR CALALLEN  02/02/2018
# 17                                           THE HALLMARK  02/08/2018
# 18                         THE HEALTHCARE RESORT OF PLANO  06/07/2017
# 19                                    WEST REST HAVEN INC  08/16/2017
# 20                             BRIGHTPOINTE AT LYTLE LAKE  05/26/2017
# 21                                    PINE SHADOW RETREAT  08/17/2017
# 22             VIBRALIFE OF EL PASO REHABILITATION CENTER  02/16/2018
# 23                                     INSPIRE NEW BOSTON  05/05/2017
# 24                                     THE BRAZOS OF WACO  01/25/2018
# 25                                 VISTA LIVING OF ARCHER  06/09/2017
# 26               MATADOR HEALTH AND REHABILITATION CENTER  08/17/2017
# 27                                     INSPIRE NEW BOSTON  05/05/2017
# 28                            WINDEMERE AT WESTOVER HILLS  05/30/2017
# 29                                       WINDSOR CALALLEN  02/02/2018
# ...                                                   ...         ...
# 344554                            FOCUSED CARE AT BRENHAM  06/25/2015
# 344555                            FOCUSED CARE AT BRENHAM  06/25/2015
# 344556                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344557                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344558                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344559                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344560                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344561                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344562                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344563                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344564                            FOCUSED CARE AT BRENHAM  02/11/2016
# 344565                         THE RIO AT MAINLAND CENTER  03/22/2016
# 344566                         THE RIO AT MAINLAND CENTER  03/22/2016
# 344567                         THE RIO AT MAINLAND CENTER  03/22/2016
# 344568                         THE RIO AT MAINLAND CENTER  02/04/2016
# 344569                         THE RIO AT MAINLAND CENTER  04/16/2016
# 344570                         THE RIO AT MAINLAND CENTER  04/16/2016
# 344571                         THE RIO AT MAINLAND CENTER  04/16/2016
# 344572                         THE RIO AT MAINLAND CENTER  04/16/2016
# 344573                         THE RIO AT MAINLAND CENTER  04/16/2016
# 344574                         THE RIO AT MAINLAND CENTER  04/16/2016
# 344575                                     HARMONEE HOUSE  05/28/2015
# 344576                                     HARMONEE HOUSE  05/28/2015
# 344577                                     HARMONEE HOUSE  05/28/2015
# 344578                                     HARMONEE HOUSE  05/28/2015
# 344579              PATHWAYS MEMORY CARE AT VILLA TOSCANA  04/07/2016
# 344580              PATHWAYS MEMORY CARE AT VILLA TOSCANA  04/07/2016
# 344581              PATHWAYS MEMORY CARE AT VILLA TOSCANA  04/07/2016
# 344582              PATHWAYS MEMORY CARE AT VILLA TOSCANA  02/18/2016
# 344583              PATHWAYS MEMORY CARE AT VILLA TOSCANA  02/18/2016
#
#        Deficiency Prefix  Deficiency Tag Number  \
# 0                      F                    322
# 1                      F                    759
# 2                      F                    498
# 3                      F                    279
# 4                      F                    387
# 5                      F                    490
# 6                      F                    309
# 7                      F                    469
# 8                      F                    319
# 9                      F                    686
# 10                     F                    319
# 11                     F                    155
# 12                     F                    309
# 13                     F                    757
# 14                     F                    284
# 15                     F                    514
# 16                     F                    636
# 17                     F                    657
# 18                     F                    309
# 19                     F                    279
# 20                     F                    328
# 21                     F                    431
# 22                     F                    623
# 23                     F                    517
# 24                     F                    760
# 25                     F                    387
# 26                     F                    354
# 27                     F                    502
# 28                     F                    226
# 29                     F                    880
# ...                  ...                    ...
# 344554                 F                    226
# 344555                 F                    323
# 344556                 F                    248
# 344557                 F                    314
# 344558                 F                    315
# 344559                 F                    318
# 344560                 F                    323
# 344561                 F                    441
# 344562                 F                    498
# 344563                 F                    514
# 344564                 F                    518
# 344565                 F                    279
# 344566                 F                    282
# 344567                 F                    309
# 344568                 F                    514
# 344569                 F                    279
# 344570                 F                    329
# 344571                 F                    224
# 344572                 F                    225
# 344573                 F                    309
# 344574                 F                    490
# 344575                 F                    167
# 344576                 F                    371
# 344577                 F                    425
# 344578                 F                    465
# 344579                 F                    157
# 344580                 F                    309
# 344581                 F                    327
# 344582                 F                    309
# 344583                 F                    514
#
#                                    Deficiency Description Scope Severity Code  \
# 0       Give proper treatment to residents with feedin...                   D
# 1       Ensure medication error rates are not 5 percen...                   E
# 2       Make sure that nurse aides show they have the ...                   E
# 3       Develop a complete care plan that meets all th...                   E
# 4       Make sure that doctors visit residents regular...                   E
# 5       Make sure that the facility is administered in...                   E
# 6       Provide necessary care and services to maintai...                   E
# 7       Make sure there is a pest control program to p...                   F
# 8       Give the right treatment and services to resid...                   E
# 9       Provide appropriate pressure ulcer care and pr...                   E
# 10      Give the right treatment and services to resid...                   K
# 11      Let residents refuse treatment, refuse to take...                   K
# 12      Provide necessary care and services to maintai...                   G
# 13      Ensure each residents drug regimen must be fr...                   E
# 14      Develop a post-discharge plan with the residen...                   D
# 15      Keep accurate, complete and organized clinical...                   F
# 16      Assess the resident completely in a timely man...                   E
# 17      Develop the complete care plan within 7 days o...                   E
# 18      Provide necessary care and services to maintai...                   E
# 19      Develop a complete care plan that meets all th...                   E
# 20      Properly care for residents needing special se...                   E
# 21      Maintain drug records and properly mark/label ...                   E
# 22      Provide timely notification to the resident, a...                   C
# 23      Have a detailed, written plan for disasters an...                   F
# 24      Ensure that residents are free from significan...                   E
# 25      Make sure that doctors visit residents regular...                   E
# 26      Use a registered nurse at least 8 hours a day,...                   E
# 27      Give or get quality laboratory services/tests ...                   F
# 28      Develop and implement policies for 1) screenin...                   G
# 29      Provide and implement an infection prevention ...                   E
# ...                                                   ...                 ...
# 344554  Develop and implement policies for 1) screenin...                   J
# 344555  Ensure that a nursing home area is free from a...                   J
# 344556  Provide activities to meet the interests and n...                   D
# 344557  Give residents proper treatment to prevent new...                   E
# 344558  Ensure that each resident who enters the nursi...                   D
# 344559  Ensure that residents with limited range of mo...                   E
# 344560  Ensure that a nursing home area is free from a...                   E
# 344561  Have a program that investigates, controls and...                   E
# 344562  Make sure that nurse aides show they have the ...                   E
# 344563  Keep accurate, complete and organized clinical...                   F
# 344564  Train all employees on what to do in an emerge...                   E
# 344565  Develop a complete care plan that meets all th...                   E
# 344566  Provide care by qualified persons according to...                   E
# 344567  Provide necessary care and services to maintai...                   E
# 344568  Keep accurate, complete and organized clinical...                   E
# 344569  Develop a complete care plan that meets all th...                   E
# 344570  Ensure that each resident's 1) entire drug/med...                   E
# 344571  Protect each resident from mistreatment, negle...                   L
# 344572  1) Hire only people with no legal history of a...                   L
# 344573  Provide necessary care and services to maintai...                   L
# 344574  Make sure that the facility is administered in...                   L
# 344575  Allow residents to easily view the results of ...                   C
# 344576  Store, cook, and serve food in a safe and clea...                   E
# 344577  Provide routine and emergency drugs through a ...                   E
# 344578  Make sure that the nursing home area is safe, ...                   E
# 344579  Immediately tell the resident, the resident's ...                   E
# 344580  Provide necessary care and services to maintai...                   E
# 344581  Give each resident enough fluids to keep them ...                   E
# 344582  Provide necessary care and services to maintai...                   G
# 344583  Keep accurate, complete and organized clinical...                   E
#
#                               Deficiency Corrected Correction Date  \
# 0       Deficient, Provider has date of correction      07/20/2017
# 1       Deficient, Provider has plan of correction      05/11/2018
# 2       Deficient, Provider has date of correction      08/15/2017
# 3       Deficient, Provider has date of correction      08/24/2017
# 4       Deficient, Provider has date of correction      06/20/2017
# 5       Deficient, Provider has date of correction      07/05/2017
# 6       Deficient, Provider has date of correction      08/15/2017
# 7       Deficient, Provider has date of correction      07/14/2017
# 8       Deficient, Provider has date of correction      06/02/2017
# 9       Deficient, Provider has date of correction      02/27/2018
# 10      Deficient, Provider has date of correction      06/01/2017
# 11      Deficient, Provider has date of correction      06/02/2017
# 12      Deficient, Provider has date of correction      07/15/2017
# 13      Deficient, Provider has plan of correction      05/09/2018
# 14      Deficient, Provider has date of correction      08/24/2017
# 15      Deficient, Provider has date of correction      06/20/2017
# 16      Deficient, Provider has date of correction      02/27/2018
# 17      Deficient, Provider has date of correction      04/20/2018
# 18      Deficient, Provider has date of correction      07/20/2017
# 19      Deficient, Provider has date of correction      09/15/2017
# 20      Deficient, Provider has date of correction      06/20/2017
# 21      Deficient, Provider has date of correction      09/22/2017
# 22      Deficient, Provider has date of correction      03/06/2018
# 23      Deficient, Provider has date of correction      06/02/2017
# 24      Deficient, Provider has date of correction      02/20/2018
# 25      Deficient, Provider has date of correction      07/24/2017
# 26      Deficient, Provider has date of correction      08/24/2017
# 27      Deficient, Provider has date of correction      06/02/2017
# 28      Deficient, Provider has date of correction      05/31/2017
# 29      Deficient, Provider has date of correction      02/27/2018
# ...                                            ...             ...
# 344554                         Past Non-Compliance      06/25/2015
# 344555                         Past Non-Compliance      06/25/2015
# 344556  Deficient, Provider has date of correction      03/18/2016
# 344557  Deficient, Provider has date of correction      03/18/2016
# 344558  Deficient, Provider has date of correction      03/18/2016
# 344559  Deficient, Provider has date of correction      03/18/2016
# 344560  Deficient, Provider has date of correction      03/18/2016
# 344561  Deficient, Provider has date of correction      03/18/2016
# 344562  Deficient, Provider has date of correction      03/18/2016
# 344563  Deficient, Provider has date of correction      03/18/2016
# 344564  Deficient, Provider has date of correction      03/18/2016
# 344565  Deficient, Provider has date of correction      03/25/2016
# 344566  Deficient, Provider has date of correction      03/25/2016
# 344567  Deficient, Provider has date of correction      03/25/2016
# 344568  Deficient, Provider has date of correction      02/29/2016
# 344569  Deficient, Provider has date of correction      04/18/2016
# 344570  Deficient, Provider has date of correction      04/18/2016
# 344571  Deficient, Provider has date of correction      04/18/2016
# 344572  Deficient, Provider has date of correction      04/18/2016
# 344573  Deficient, Provider has date of correction      04/18/2016
# 344574  Deficient, Provider has date of correction      04/18/2016
# 344575  Deficient, Provider has date of correction      06/20/2015
# 344576  Deficient, Provider has date of correction      06/20/2015
# 344577  Deficient, Provider has date of correction      06/20/2015
# 344578  Deficient, Provider has date of correction      06/20/2015
# 344579  Deficient, Provider has date of correction      04/09/2016
# 344580  Deficient, Provider has date of correction      04/09/2016
# 344581  Deficient, Provider has date of correction      04/09/2016
# 344582  Deficient, Provider has date of correction      03/18/2016
# 344583  Deficient, Provider has date of correction      03/18/2016
#
#         Standard Deficiency  Complaint Deficiency Provider State  \
# 0                      True                 False             TX
# 1                      True                 False             TX
# 2                      True                 False             TX
# 3                      True                 False             TX
# 4                      True                 False             TX
# 5                      True                 False             TX
# 6                      True                 False             TX
# 7                      True                  True             TX
# 8                      True                 False             TX
# 9                      True                 False             TX
# 10                     True                  True             TX
# 11                     True                 False             TX
# 12                    False                  True             TX
# 13                     True                 False             TX
# 14                     True                 False             TX
# 15                     True                  True             TX
# 16                     True                 False             TX
# 17                     True                 False             TX
# 18                     True                 False             TX
# 19                     True                 False             TX
# 20                     True                 False             TX
# 21                     True                 False             TX
# 22                    False                  True             TX
# 23                     True                 False             TX
# 24                     True                 False             TX
# 25                     True                 False             TX
# 26                     True                 False             TX
# 27                     True                 False             TX
# 28                     True                  True             TX
# 29                     True                 False             TX
# ...                     ...                   ...            ...
# 344554                False                  True             TX
# 344555                False                  True             TX
# 344556                 True                 False             TX
# 344557                 True                 False             TX
# 344558                 True                 False             TX
# 344559                 True                 False             TX
# 344560                 True                 False             TX
# 344561                 True                 False             TX
# 344562                 True                 False             TX
# 344563                 True                 False             TX
# 344564                 True                 False             TX
# 344565                False                  True             TX
# 344566                False                  True             TX
# 344567                False                  True             TX
# 344568                False                  True             TX
# 344569                 True                 False             TX
# 344570                 True                 False             TX
# 344571                 True                  True             TX
# 344572                 True                  True             TX
# 344573                 True                  True             TX
# 344574                 True                  True             TX
# 344575                 True                 False             TX
# 344576                 True                 False             TX
# 344577                 True                 False             TX
# 344578                 True                 False             TX
# 344579                False                  True             TX
# 344580                False                  True             TX
# 344581                False                  True             TX
# 344582                False                  True             TX
# 344583                False                  True             TX
#
#                                                  Location Processing Date  \
# 0       3325 WEST PLANO PARKWAY\nPLANO, TX 75075\n(33....      06/01/2018
# 1       2625 BELT LINE ROAD\nGARLAND, TX 75044\n(32.94...      06/01/2018
# 2       16550 RETAMA PARKWAY\nSELMA, TX 78154\n(29.589...      06/01/2018
# 3       805 HARRISON ST\nMATADOR, TX 79244\n(34.024466...      06/01/2018
# 4       1201 CLARKS DR\nABILENE, TX 79602\n(32.439629,...      06/01/2018
# 5       210 RICE ST\nNEW BOSTON, TX 75570\n(33.46167, ...      06/01/2018
# 6       16550 RETAMA PARKWAY\nSELMA, TX 78154\n(29.589...      06/01/2018
# 7       2100 CANNON DR\nMANSFIELD, TX 76063\n(32.57715...      06/01/2018
# 8       210 RICE ST\nNEW BOSTON, TX 75570\n(33.46167, ...      06/01/2018
# 9       4162 WILDCAT DR\nCORPUS CHRISTI, TX 78410\n(27...      06/01/2018
# 10      1201 CLARKS DR\nABILENE, TX 79602\n(32.439629,...      06/01/2018
# 11      210 RICE ST\nNEW BOSTON, TX 75570\n(33.46167, ...      06/01/2018
# 12      25150 LAKECREST MANOR DR\nKATY, TX 77493\n(29....      06/01/2018
# 13      2625 BELT LINE ROAD\nGARLAND, TX 75044\n(32.94...      06/01/2018
# 14      805 HARRISON ST\nMATADOR, TX 79244\n(34.024466...      06/01/2018
# 15      1201 CLARKS DR\nABILENE, TX 79602\n(32.439629,...      06/01/2018
# 16      4162 WILDCAT DR\nCORPUS CHRISTI, TX 78410\n(27...      06/01/2018
# 17      4718 HALLMARK DR\nHOUSTON, TX 77056\n(29.75029...      06/01/2018
# 18      3325 WEST PLANO PARKWAY\nPLANO, TX 75075\n(33....      06/01/2018
# 19      503 MEADOW DRIVE\nWEST, TX 76691\n(31.817289, ...      06/01/2018
# 20      1201 CLARKS DR\nABILENE, TX 79602\n(32.439629,...      06/01/2018
# 21      23450 PINE SHADOW LN\nPORTER, TX 77365\n(30.10...      06/01/2018
# 22      3421 JOE BATTLE BOULEVARD\nEL PASO, TX 79936\n...      06/01/2018
# 23      210 RICE ST\nNEW BOSTON, TX 75570\n(33.46167, ...      06/01/2018
# 24      2430 MARKET PLACE DRIVE\nWACO, TX 76711\n(31.5...      06/01/2018
# 25      201 E CHESTNUT ST\nARCHER CITY, TX 76351\n(33....      06/01/2018
# 26      805 HARRISON ST\nMATADOR, TX 79244\n(34.024466...      06/01/2018
# 27      210 RICE ST\nNEW BOSTON, TX 75570\n(33.46167, ...      06/01/2018
# 28      11106 CHRISTUS HILLS\nSAN ANTONIO, TX 78251\n(...      06/01/2018
# 29      4162 WILDCAT DR\nCORPUS CHRISTI, TX 78410\n(27...      06/01/2018
# ...                                                   ...             ...
# 344554                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344555                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344556                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344557                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344558                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344559                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344560                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344561                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344562                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344563                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344564                      1303 HWY\nBRENHAM, TX 77833\n      06/01/2018
# 344565    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344566    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344567    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344568    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344569    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344570    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344571    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344572    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344573    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344574    1011 MAINLAND CENTER DR\nTEXAS CITY, TX 77591\n      06/01/2018
# 344575                  1400 MAIN ST\nAMHERST, TX 79312\n      06/01/2018
# 344576                  1400 MAIN ST\nAMHERST, TX 79312\n      06/01/2018
# 344577                  1400 MAIN ST\nAMHERST, TX 79312\n      06/01/2018
# 344578                  1400 MAIN ST\nAMHERST, TX 79312\n      06/01/2018
# 344579    2930 CYPRESS GROVE MEADOWS\nHOUSTON, TX 77014\n      06/01/2018
# 344580    2930 CYPRESS GROVE MEADOWS\nHOUSTON, TX 77014\n      06/01/2018
# 344581    2930 CYPRESS GROVE MEADOWS\nHOUSTON, TX 77014\n      06/01/2018
# 344582    2930 CYPRESS GROVE MEADOWS\nHOUSTON, TX 77014\n      06/01/2018
# 344583    2930 CYPRESS GROVE MEADOWS\nHOUSTON, TX 77014\n      06/01/2018
#
#                                      filename
# 0       Deficiencies/Deficiencies Cycle 1.csv
# 1       Deficiencies/Deficiencies Cycle 1.csv
# 2       Deficiencies/Deficiencies Cycle 1.csv
# 3       Deficiencies/Deficiencies Cycle 1.csv
# 4       Deficiencies/Deficiencies Cycle 1.csv
# 5       Deficiencies/Deficiencies Cycle 1.csv
# 6       Deficiencies/Deficiencies Cycle 1.csv
# 7       Deficiencies/Deficiencies Cycle 1.csv
# 8       Deficiencies/Deficiencies Cycle 1.csv
# 9       Deficiencies/Deficiencies Cycle 1.csv
# 10      Deficiencies/Deficiencies Cycle 1.csv
# 11      Deficiencies/Deficiencies Cycle 1.csv
# 12      Deficiencies/Deficiencies Cycle 1.csv
# 13      Deficiencies/Deficiencies Cycle 1.csv
# 14      Deficiencies/Deficiencies Cycle 1.csv
# 15      Deficiencies/Deficiencies Cycle 1.csv
# 16      Deficiencies/Deficiencies Cycle 1.csv
# 17      Deficiencies/Deficiencies Cycle 1.csv
# 18      Deficiencies/Deficiencies Cycle 1.csv
# 19      Deficiencies/Deficiencies Cycle 1.csv
# 20      Deficiencies/Deficiencies Cycle 1.csv
# 21      Deficiencies/Deficiencies Cycle 1.csv
# 22      Deficiencies/Deficiencies Cycle 1.csv
# 23      Deficiencies/Deficiencies Cycle 1.csv
# 24      Deficiencies/Deficiencies Cycle 1.csv
# 25      Deficiencies/Deficiencies Cycle 1.csv
# 26      Deficiencies/Deficiencies Cycle 1.csv
# 27      Deficiencies/Deficiencies Cycle 1.csv
# 28      Deficiencies/Deficiencies Cycle 1.csv
# 29      Deficiencies/Deficiencies Cycle 1.csv
# ...                                       ...
# 344554  Deficiencies/Deficiencies Cycle 3.csv
# 344555  Deficiencies/Deficiencies Cycle 3.csv
# 344556  Deficiencies/Deficiencies Cycle 3.csv
# 344557  Deficiencies/Deficiencies Cycle 3.csv
# 344558  Deficiencies/Deficiencies Cycle 3.csv
# 344559  Deficiencies/Deficiencies Cycle 3.csv
# 344560  Deficiencies/Deficiencies Cycle 3.csv
# 344561  Deficiencies/Deficiencies Cycle 3.csv
# 344562  Deficiencies/Deficiencies Cycle 3.csv
# 344563  Deficiencies/Deficiencies Cycle 3.csv
# 344564  Deficiencies/Deficiencies Cycle 3.csv
# 344565  Deficiencies/Deficiencies Cycle 3.csv
# 344566  Deficiencies/Deficiencies Cycle 3.csv
# 344567  Deficiencies/Deficiencies Cycle 3.csv
# 344568  Deficiencies/Deficiencies Cycle 3.csv
# 344569  Deficiencies/Deficiencies Cycle 3.csv
# 344570  Deficiencies/Deficiencies Cycle 3.csv
# 344571  Deficiencies/Deficiencies Cycle 3.csv
# 344572  Deficiencies/Deficiencies Cycle 3.csv
# 344573  Deficiencies/Deficiencies Cycle 3.csv
# 344574  Deficiencies/Deficiencies Cycle 3.csv
# 344575  Deficiencies/Deficiencies Cycle 3.csv
# 344576  Deficiencies/Deficiencies Cycle 3.csv
# 344577  Deficiencies/Deficiencies Cycle 3.csv
# 344578  Deficiencies/Deficiencies Cycle 3.csv
# 344579  Deficiencies/Deficiencies Cycle 3.csv
# 344580  Deficiencies/Deficiencies Cycle 3.csv
# 344581  Deficiencies/Deficiencies Cycle 3.csv
# 344582  Deficiencies/Deficiencies Cycle 3.csv
# 344583  Deficiencies/Deficiencies Cycle 3.csv
#
# [344584 rows x 15 columns]

# %%
plt.style.use('ggplot')

severity_count = everything.groupby(by='Scope Severity Code')['Provider State'].count()
severity_count.sort_values(ascending=False)
severity_count
# Out:
# Scope Severity Code
# B      6024
# C      7001
# D    197886
# E     91324
# F     24665
# G     10710
# H       982
# I        32
# J      2872
# K      2318
# L       770
# Name: Provider State, dtype: int64

# %%
bar_coloring = ['#742f35', '#948282', '#9f6969', '#d05b5b', '#786565', '#401515', '#8b594c'] 
ax = severity_count.plot(kind='pie', colors=bar_coloring, legend=True)
plt.legend(loc="upper right", bbox_to_anchor=(1.25,1))

ax.set_title("The Most Common Type of Nursing Home Problems", pad=30, fontsize=20)
ax.title.set_fontname('Lao Sangam MN')

plt.gcf().text(0.5, .93, "Nursing home deficiencies are ranked on a scale of A to L, with L being the most severe.", ha='center', fontsize=10)
# Out:
# Text(0.5,0.93,'Nursing home deficiencies are ranked on a scale of A to L, with L being the most severe.')

# %%
deficiency_count = everything.groupby(by='Provider State')['Deficiency Description'].count()
deficiency_count.sort_values(ascending=False).head(15)
# Out:
# Provider State
# CA    43434
# TX    26608
# IL    19086
# OH    18108
# PA    17515
# MI    14703
# FL    13061
# IN    12630
# KS    10506
# MO    10266
# NY     9848
# WA     8641
# WI     8357
# OK     8181
# MD     7811
# Name: Deficiency Description, dtype: int64

# %%
elders.sort_values(by='Elderly_Depression', ascending=True).plot(kind='barh', x='State', y=['State_Depression_Average', 'Elderly_Depression'], figsize=(10, 20))
