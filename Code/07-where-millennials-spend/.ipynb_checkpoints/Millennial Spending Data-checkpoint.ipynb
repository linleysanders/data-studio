# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mil = pd.read_csv('millennial-spending-update.csv')
mil
# Out:
#                     Unnamed: 0  All households  Baby Boomers  Generation X  \
# 0                         Food            12.6          12.0          12.9
# 1                 Food at home             7.1           6.9           7.0
# 2          Food away from home             5.5           5.1           5.9
# 3                      Housing            33.0          30.9          33.1
# 4              Owned dwellings            11.0          11.8          11.9
# 5             Rented dwellings             7.0           3.9           6.6
# 6           Telephone services             2.5           2.5           2.5
# 7   Residential phone services             0.5           0.6           0.4
# 8       Cellular phone service             2.0           1.9           2.1
# 9         Apparel and services             3.1           2.6           3.8
# 10              Transportation            15.8          15.9          15.4
# ...

# %%
mil = mil[['Unnamed: 0', 'All households', 'Greatest Gen', 'Silent Gen', 'Baby Boomers', 'Generation X', 'Millenials']]

# %%
mil
# Out:
#                     Unnamed: 0  All households  Greatest Gen  Silent Gen  \
# 0                         Food            12.6           8.8        13.2
# 1                 Food at home             7.1           5.7         8.3
# 2          Food away from home             5.5           3.1         4.9
# 3                      Housing            33.0          50.5        34.5
# 4              Owned dwellings            11.0           8.9        11.9
# 5             Rented dwellings             7.0          23.4         5.4
# 6           Telephone services             2.5           2.0         2.5
# 7   Residential phone services             0.5           1.4         1.2
# 8       Cellular phone service             2.0           0.6         1.3
# 9         Apparel and services             3.1           1.7         2.2
# 10              Transportation            15.8           8.9        14.3
# 11         New cars and trucks             2.9           3.2         3.6
# ...

# %%
mil.to_csv("ordered-millennials.csv", index=False)

# %%
mil.rename(columns={'Unnamed: 0': 'Category'}, inplace=True)

# %%
#Greatest: Born 1927 or earlier
#Silent: 1928–1945
#Baby Boomers: 1946–1964
#Generation X: 1965–1980
#Millenials: 1981–present
mil
# Out:
#                       Category  All households  Greatest Gen  Silent Gen  \
# 0                         Food            12.6           8.8        13.2
# 1                 Food at home             7.1           5.7         8.3
# 2          Food away from home             5.5           3.1         4.9
# 3                      Housing            33.0          50.5        34.5
# 4              Owned dwellings            11.0           8.9        11.9
# 5             Rented dwellings             7.0          23.4         5.4
# 6           Telephone services             2.5           2.0         2.5
# 7   Residential phone services             0.5           1.4         1.2
# 8       Cellular phone service             2.0           0.6         1.3
# 9         Apparel and services             3.1           1.7         2.2
# 10              Transportation            15.8           8.9        14.3
# 11         New cars and trucks             2.9           3.2         3.6
# ...
